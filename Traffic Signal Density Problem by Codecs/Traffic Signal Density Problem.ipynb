# %%
import sys
import os
import numpy
import pandas
import matplotlib
import seaborn

# %%
print('Python: {}'.format(sys.version))
print('Numpy: {}'.format(numpy.__version__))
print('pandas: {}'.format(pandas.__version__))
print('matplotlib: {}'.format(matplotlib.__version__))
print('seaborn: {}'.format(seaborn.__version__))
# Out:
# Python: 3.6.5 |Anaconda, Inc.| (default, Mar 29 2018, 13:32:41) [MSC v.1900 64 bit (AMD64)]
# Numpy: 1.14.3
# pandas: 0.23.0
# matplotlib: 2.2.2
# seaborn: 0.8.1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
da=pd.read_csv('signnames.csv')

# %%
print(da.columns)
# Out:
# Index(['ClassId', 'SignName'], dtype='object')

# %%
print(da.shape)
# Out:
# (43, 2)

# %%
print(da.describe())
# Out:
#          ClassId
# count  43.000000
# mean   21.000000
# std    12.556539
# min     0.000000
# 25%    10.500000
# 50%    21.000000
# 75%    31.500000
# max    42.000000

# %%
print(data6)
# Out:
#     ClassId                                           SignName
# 0         0                               Speed limit (20km/h)
# 1         1                               Speed limit (30km/h)
# 2         2                               Speed limit (50km/h)
# 3         3                               Speed limit (60km/h)
# 4         4                               Speed limit (70km/h)
# 5         5                               Speed limit (80km/h)
# 6         6                        End of speed limit (80km/h)
# 7         7                              Speed limit (100km/h)
# 8         8                              Speed limit (120km/h)
# 9         9                                         No passing
# 10       10       No passing for vehicles over 3.5 metric tons
# 11       11              Right-of-way at the next intersection
# 12       12                                      Priority road
# 13       13                                              Yield
# 14       14                                               Stop
# 15       15                                        No vehicles
# 16       16           Vehicles over 3.5 metric tons prohibited
# 17       17                                           No entry
# 18       18                                    General caution
# 19       19                        Dangerous curve to the left
# 20       20                       Dangerous curve to the right
# 21       21                                       Double curve
# 22       22                                         Bumpy road
# 23       23                                      Slippery road
# 24       24                          Road narrows on the right
# 25       25                                          Road work
# 26       26                                    Traffic signals
# 27       27                                        Pedestrians
# 28       28                                  Children crossing
# 29       29                                  Bicycles crossing
# 30       30                                 Beware of ice/snow
# 31       31                              Wild animals crossing
# 32       32                End of all speed and passing limits
# 33       33                                   Turn right ahead
# 34       34                                    Turn left ahead
# 35       35                                         Ahead only
# 36       36                               Go straight or right
# 37       37                                Go straight or left
# 38       38                                         Keep right
# 39       39                                          Keep left
# 40       40                               Roundabout mandatory
# 41       41                                  End of no passing
# 42       42  End of no passing by vehicles over 3.5 metric ...

# %%
import pickle as pickle

# %%
da.hist(figsize = (20,20))
plt.show()

# %%
def load_pickled_data(file,columns):
    with open(file,mode='rb') as f:
        dataset = pickle.load(f)
        return tuple(map(lambda c:data[c],columns))

# %%
train_dataset_file = 'traffic-signs-data/train.p'
test_dataset_file = 'traffic-signs-data/test.p'

# %%
X_train,y_train = load_pickled_data(train_dataset_file,['features','labels'])
X_test,y_test = load_pickled_data(test_dataset_file,['features','labels'])
n_train = y_train.shape[0]
n_test = y_test.shape[0]
image_shape = x_train[0].shape
n_classes=len(set(y_train))
print("number of training examples =",n_train)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-83-c212d1ee7b24> in <module>()
# ----> 1 X_train,y_train = load_pickled_data(train_dataset_file,['features','labels'])
#       2 X_test,y_test = load_pickled_data(test_dataset_file,['features','labels'])
#       3 n_train = y_train.shape[0]
#       4 n_test = y_test.shape[0]
#       5 image_shape = x_train[0].shape
#
# <ipython-input-75-d40fbd51aec6> in load_pickled_data(file, columns)
#       1 def load_pickled_data(file,columns):
# ----> 2     with open(file,mode='rb') as f:
#       3         dataset = pickle.load(f)
#       4         return tuple(map(lambda c:data[c],columns))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'traffic-signs-data/train.p'

# %%
data = np.random.rand(20,18)
da=sns.heatmap(data)
